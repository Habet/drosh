# %%
import imageio
import matplotlib.pyplot as plt
import scipy.ndimage as ndi
import numpy as np

# %% [markdown]
# Նկարը

# %%
z1 = plt.imread('drosh2.jpg')
plt.imshow(z1)
plt.show()

# %% [markdown]
# Երրորդ գույնը

# %%
z2 = z1[150:200,300:345,]
plt.imshow(z2)
#plt.axis('off')
plt.show()

# %% [markdown]
# Միջինը

# %%
z2.mean(axis= (0,1))
# Out:
# array([230.80888889, 171.10488889,  91.76177778])

# %% [markdown]
# Նորագավթի դրոշի դեղինը

# %%
plt.imshow([[(230, 171, 91)]])

# %% [markdown]
# Հայկական դրոշի դեղինը

# %%
plt.imshow([[(242, 168, 0)]])

# %% [markdown]
# Կոլումբիայի դրոշի դեղինը

# %%
plt.imshow([[(252,209,22)]])
